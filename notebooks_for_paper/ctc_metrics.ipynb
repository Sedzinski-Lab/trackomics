# %%
from ctc_metrics import evaluate_sequence, validate_sequence

# %%
# Validate the sequence
res = validate_sequence("nuclei_membrane_tracking/10_RES")
print(res["Valid"])
# Out:
# 1D:/Mari_Test_Dataset_Analysis/nuclei_membrane_tracking/10_RES

# %%
# Evaluate the sequence
res = evaluate_sequence("nuclei_membrane_tracking/10_RES/", "D:/Mari/nucleus_tracking_datasets/2021-10-20/tracking_gt/gt/01_ST")
print(res["DET"])
print(res["TRA"])
print(res["LNK"])
print(res["TF"])
print(res["CCA"])
print(res["CT"])
print(res["BC"])
# Out:
# Evaluate sequence:  D:/Mari_Test_Dataset_Analysis/nuclei_membrane_tracking/10_RES/  with ground truth:  D:/Mari/nucleus_tracking_datasets/2021-10-20/tracking_gt/gt/01_ST['D:/Mari/nucleus_tracking_datasets/2021-10-20/tracking_gt/gt/01_ST\\SEG\\man_seg000.tif', 'D:/Mari/nucleus_tracking_datasets/2021-10-20/tracking_gt/gt/01_ST\\SEG\\man_seg001.tif', 'D:/Mari/nucleus_tracking_datasets/2021-10-20/tracking_gt/gt/01_ST\\SEG\\man_seg002.tif', 'D:/Mari/nucleus_tracking_datasets/2021-10-20/tracking_gt/gt/01_ST\\SEG\\man_seg003.tif', 'D:/Mari/nucleus_tracking_datasets/2021-10-20/tracking_gt/gt/01_ST\\SEG\\man_seg004.tif', 'D:/Mari/nucleus_tracking_datasets/2021-10-20/tracking_gt/gt/01_ST\\SEG\\man_seg005.tif', 'D:/Mari/nucleus_tracking_datasets/2021-10-20/tracking_gt/gt/01_ST\\SEG\\man_seg006.tif', 'D:/Mari/nucleus_tracking_datasets/2021-10-20/tracking_gt/gt/01_ST\\SEG\\man_seg007.tif', 'D:/Mari/nucleus_tracking_datasets/2021-10-20/tracking_gt/gt/01_ST\\SEG\\man_seg008.tif', 'D:/Mari/nucleus_t
# ...
