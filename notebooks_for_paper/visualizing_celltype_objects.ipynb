# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tifffile as tiff

# %%
full_df = pd.read_csv("nuclei_membrane_tracking/full_manual_dataset_cropped.csv")

# %%
full_df2 = full_df[full_df['cell_type'] != 'unknown']

# %%
full_df2_final = full_df2[full_df2['t'] == 359]

# %%
full_df2_final.columns.to_list()

# %%
full_df2_final['ID'].value_counts()

# %%
def construct_lineages(df, complete_df):
    # Extract the last timepoint dataframe
    last_timepoint_df = df[df['t'] == df['t'].max()]
    last_ids = last_timepoint_df[['ID', 'cell_type', 'Spot track ID relabelled']]

    # Initialize the lineages dictionary
    lineages = {}

    # Iterate over each ID in the last timepoint
    for _, row in last_ids.iterrows():
        current_id = row['ID']
        cell_type = row['cell_type']
        track_id = row['Spot track ID relabelled']
        lineage_ids = []
        n_mem_labels = 0

        print(f'Processing id {current_id}')

        # Trace lineage
        while not pd.isna(current_id):
            lineage_ids.append(current_id)
            #print(current_id)

            if len(complete_df[complete_df['ID'] == current_id]) > 0:
                # Find the row corresponding to the current ID
                current_row = complete_df[complete_df['ID'] == current_id].iloc[0]

                # Check mem_label
                if not pd.isna(current_row['mem_label']) and current_row['mem_label'] != 0:
                    n_mem_labels += 1

                # Move to the source_ID
                current_id = current_row['Spot source ID']
            else:
                current_id = pd.NA

        # Add to lineages dictionary
        lineages[row['ID']] = {
            'cell_type': cell_type,
            'lineage_ids': lineage_ids,
            'track_id' : track_id,
            'n_mem_labels': n_mem_labels
        }

    return lineages

lineages = construct_lineages(full_df2, full_df)
# Out:
# Processing id 1902
# Processing id 1903
# Processing id 1905
# Processing id 36440
# Processing id 36441
# Processing id 36442
# Processing id 36443
# Processing id 36445
# Processing id 36446
# Processing id 36448
# Processing id 36449
# Processing id 36450
# Processing id 36452
# Processing id 36453
# Processing id 36454
# Processing id 36455
# Processing id 36456
# Processing id 36457
# Processing id 36458
# Processing id 36459
# Processing id 36460
# Processing id 36461
# Processing id 36462
# Processing id 36463
# Processing id 36464
# Processing id 36465
# Processing id 36466
# Processing id 36467
# Processing id 36468
# Processing id 36469
# Processing id 36470
# Processing id 36471
# Processing id 36472
# Processing id 36474
# Processing id 36475
# Processing id 36476
# Processing id 36477
# Processing id 36479
# Processing id 36480
# Processing id 36481
# Processing id 36482
# Processing id 36483
# Processing id 36484
# Processing id 36485
# Processing id 36487
# Processing id 36488
# Processing id 36489
# Processing id 36491
# Processing id 36492
# Processing id 36493
# Processing id 36494
# Processing id 36495
# Processing id 36496
# Processing id 36497
# Processing id 36498
# Processing id 36499
# Processing id 36500
# Processing id 36501
# Processing id 36502
# Processing id 36503
# Processing id 36504
# Processing id 36505
# Processing id 36506
# Processing id 36507
# Processing id 36509
# Processing id 36510
# Processing id 36511
# Processing id 36513
# Processing id 36515
# Processing id 36518
# Processing id 36519
# Processing id 36520
# Processing id 36521
# Processing id 36522
# Processing id 36523
# Processing id 36525
# Processing id 36526
# Processing id 36527
# Processing id 36528
# Processing id 36529
# Processing id 36530
# Processing id 36531
# Processing id 36536
# Processing id 36537
# Processing id 36538
# Processing id 745075
# Processing id 745081
# Processing id 745083
# Processing id 745085
# Processing id 745086
# Processing id 745087
# Processing id 745090
# Processing id 745092
# Processing id 745096
# Processing id 745097
# Processing id 745099
# Processing id 745101
# Processing id 745103
# Processing id 745104
# Processing id 745108
# Processing id 745111
# Processing id 745112
# Processing id 745113
# Processing id 745115
# Processing id 745116
# Processing id 745119
# Processing id 745120
# Processing id 745121
# Processing id 745123
# Processing id 745124
# Processing id 745125
# Processing id 745126
# Processing id 745131
# Processing id 745133
# Processing id 745135
# Processing id 745136
# Processing id 745137
# Processing id 745145
# Processing id 745150
# Processing id 745151
# Processing id 745155
# Processing id 745158
# Processing id 745160
# Processing id 745161
# Processing id 745162
# Processing id 745165
# Processing id 745167
# Processing id 745168
# Processing id 745174
# Processing id 745176
# Processing id 745177
# Processing id 745179
# Processing id 745201
# Processing id 745206
# Processing id 745210
# Processing id 745213
# Processing id 745214
# Processing id 745221
# Processing id 745222
# Processing id 745223
# Processing id 745227
# Processing id 745235
# Processing id 745237
# Processing id 745241
# Processing id 745242
# Processing id 745243
# Processing id 745244
# Processing id 745248
# Processing id 745250
# Processing id 745252
# Processing id 745261
# Processing id 745264
# Processing id 745269
# Processing id 745271
# Processing id 745272
# Processing id 745276
# Processing id 745282
# Processing id 745285
# Processing id 745296
# Processing id 745301
# Processing id 745310
# Processing id 745327
# Processing id 745341
# Processing id 745345
# Processing id 745346
# Processing id 745357
# Processing id 745359
# Processing id 745361
# Processing id 745371
# Processing id 745373
# Processing id 745374
# Processing id 745383
# Processing id 745389
# Processing id 745405
# Processing id 745410
# Processing id 745411
# Processing id 745419
# Processing id 745422
# Processing id 745428
# Processing id 745431
# Processing id 745450
# Processing id 745467
# Processing id 745474
# Processing id 745490
# Processing id 745498
# Processing id 745509
# Processing id 745525
# Processing id 745526
# Processing id 745537
# Processing id 745538
# Processing id 745546
# Processing id 745547
# Processing id 745548
# Processing id 745555
# Processing id 745556
# Processing id 745595

# %%
lineages

# %%
def find_top_lineages_and_subset_df(df, lineages, top_n=10):
    # Convert lineages dictionary to a dataframe
    lineages_df = pd.DataFrame([
        {'ID': key, 'cell_type': value['cell_type'], 'n_mem_labels': value['n_mem_labels'], 'lineage_ids': value['lineage_ids']}
        for key, value in lineages.items()
    ])

    # Find top IDs by n_mem_labels for each cell_type
    top_lineages = (
        lineages_df.sort_values(['cell_type', 'n_mem_labels'], ascending=[True, False])
        .groupby('cell_type')
        .head(top_n)
    )

    # Initialize an empty list to store rows for the subset dataframe
    rows = []

    # Extract relevant rows for each selected lineage
    for _, row in top_lineages.iterrows():
        lineage_ids = row['lineage_ids']
        # Get rows from the original dataframe corresponding to lineage IDs
        lineage_rows = df[df['ID'].isin(lineage_ids)][['Spot track ID relabelled', 'Track ID_y', 'cell_type', 't', 'mem_label', 'mem_x', 'mem_y', 'mem_z']]
        rows.append(lineage_rows)

    # Combine all rows into a subset dataframe
    subset_df = pd.concat(rows, ignore_index=True)

    return subset_df

# %%
def find_top_lineages_and_subset_df(df, lineages, top_n=10):
    # Convert lineages dictionary to a dataframe
    lineages_df = pd.DataFrame([
        {
            'ID': key,
            'cell_type': value['cell_type'],
            'n_mem_labels': value['n_mem_labels'],
            'lineage_ids': value['lineage_ids'],
            'track_id': value['track_id']
        }
        for key, value in lineages.items()
    ])

    # For each track_id, keep the row with the highest n_mem_labels
    lineages_df = (
        lineages_df.sort_values('n_mem_labels', ascending=False)
        .drop_duplicates(subset=['track_id'], keep='first')
    )

    # Find the top `top_n` IDs for each cell_type by n_mem_labels
    top_lineages = (
        lineages_df.sort_values(['cell_type', 'n_mem_labels'], ascending=[True, False])
        .groupby('cell_type')
        .head(top_n)
    )

    # Initialize an empty list to store rows for the subset dataframe
    rows = []

    # Extract relevant rows for each selected lineage
    for _, row in top_lineages.iterrows():
        lineage_ids = row['lineage_ids']
        # Get rows from the original dataframe corresponding to lineage IDs
        lineage_rows = df[df['ID'].isin(lineage_ids)][['Spot track ID relabelled', 'Track ID_y', 'cell_type', 't', 'mem_label', 'mem_x', 'mem_y', 'mem_z']]
        rows.append(lineage_rows)

    # Combine all rows into a subset dataframe
    subset_df = pd.concat(rows, ignore_index=True)

    return subset_df

# %%
# Example usage:
subset_df = find_top_lineages_and_subset_df(full_df2, lineages, top_n=5)

# %%
subset_df['cell_type'].value_counts()

# %%
def remap_track_ids_simple(subset_df):
    # Group by cell_type and enumerate Track IDs within each group
    subset_df['Track ID_remapped'] = (
        subset_df.groupby('cell_type')['Spot track ID relabelled']
        .transform(lambda x: pd.Categorical(x).codes)
    )
    return subset_df

# Example usage:
subset_df = remap_track_ids_simple(subset_df)

# %%
subset_df['Track ID_remapped'].max()

# %%
subset_df

# %%
full_mem_array = tiff.imread('seg_membrane_timelapses_fixed/timelapse_sixth_dataset.tif')

# %%
# Pad the z-axis of the original image array with 3 slices in both directions
padded_mem_array = np.pad(
    full_mem_array,
    pad_width=((0, 0), (3, 3), (0, 0), (0, 0)),  # Only pad the Z-axis
    mode='constant',  # Use constant values (e.g., zero padding)
    constant_values=0  # Pad with zeros
)

# %%
del full_mem_array

# %%
import gc
gc.collect()
# Out:
# 48

# %%
# Generate the croppings array
def generate_croppings(df, image_array):
    C, N, T, Z, Y, X = 5, 5, 360, 10, 150, 150
    croppings = np.zeros((C, N, T, Z, Y, X), dtype=bool)

    # Map cell types to indices (0-4)
    cell_type_to_idx = {cell_type: i for i, cell_type in enumerate(df['cell_type'].unique())}

    # Process each group of cell_type and Track ID
    for (cell_type, track_id), group in df.groupby(['cell_type', 'Track ID_remapped']):
        print(f'Processing cell type: {cell_type}, Track ID: {track_id}')
        c_idx = cell_type_to_idx[cell_type]
        n_idx = list(df['Track ID_remapped'].unique()).index(track_id)

        for t in range(T):  # Iterate over timepoints
            if t in group['t'].values:
                row = group[
                    (group['t'] == t)].iloc[0]
                
                mem_label, mem_x, mem_y, mem_z = row['mem_label'], row['mem_x'], row['mem_y'], row['mem_z']

                if not pd.isna(mem_x):
                    mem_label, mem_x, mem_y, mem_z = int(mem_label), int(mem_x), int(mem_y), int(mem_z)
                    
                    # Define cropping bounds
                    z_min, z_max = mem_z - 5, mem_z + 5
                    y_min, y_max = mem_y - 75, mem_y + 75
                    x_min, x_max = mem_x - 75, mem_x + 75

                    # Ensure bounds stay within image dimensions
                    z_min_pad, z_max_pad = max(0, z_min), min(image_array.shape[1], z_max)
                    y_min_pad, y_max_pad = max(0, y_min), min(image_array.shape[2], y_max)
                    x_min_pad, x_max_pad = max(0, x_min), min(image_array.shape[3], x_max)

                    # Extract crop and ensure it matches target shape
                    crop = image_array[
                        t, z_min_pad:z_max_pad, y_min_pad:y_max_pad, x_min_pad:x_max_pad
                    ] == mem_label
                    
                    # Pad crop to (10, 150, 150) if necessary
                    crop = np.pad(
                        crop,
                        pad_width=(
                            (0, 10 - crop.shape[0]),  # Z-axis padding
                            (0, 150 - crop.shape[1]),  # Y-axis padding
                            (0, 150 - crop.shape[2])   # X-axis padding
                        ),
                        mode='constant',
                        constant_values=0
                    )

                    # Assign to croppings array
                    croppings[c_idx, n_idx, t] = crop
                else:
                    continue
            else:
                # Leave as empty array for missing timepoints
                continue

    return croppings

# %%
subset_df['Spot track ID relabelled'].value_counts()

# %%
croppings_array = generate_croppings(subset_df, padded_mem_array)
# Out:
# Processing cell type: basal, Track ID: 0
# Processing cell type: basal, Track ID: 1
# Processing cell type: basal, Track ID: 2
# Processing cell type: basal, Track ID: 3
# Processing cell type: basal, Track ID: 4
# Processing cell type: goblet, Track ID: 0
# Processing cell type: goblet, Track ID: 1
# Processing cell type: goblet, Track ID: 2
# Processing cell type: goblet, Track ID: 3
# Processing cell type: goblet, Track ID: 4
# Processing cell type: ic, Track ID: 0
# Processing cell type: ic, Track ID: 1
# Processing cell type: ic, Track ID: 2
# Processing cell type: ic, Track ID: 3
# Processing cell type: ic, Track ID: 4
# Processing cell type: mcc, Track ID: 0
# Processing cell type: mcc, Track ID: 1
# Processing cell type: mcc, Track ID: 2
# Processing cell type: mcc, Track ID: 3
# Processing cell type: mcc, Track ID: 4
# Processing cell type: ssc, Track ID: 0
# Processing cell type: ssc, Track ID: 1
# Processing cell type: ssc, Track ID: 2
# Processing cell type: ssc, Track ID: 3
# Processing cell type: ssc, Track ID: 4

# %%
del padded_mem_array

gc.collect()
# Out:
# 0

# %%
len(croppings_array[croppings_array == True])

# %%
celltype_dict = {0 : 'basal', 1 : 'goblet', 2 : 'ic', 3 : 'mcc', 4 : 'ssc'}

# %%
croppings_array.shape

# %%
# %%capture
#import ncolor
mask = croppings_array
#mask_nc = ncolor.label(mask,max_depth=20)

import napari
viewer = napari.view_labels(mask)
voxel_size_x = 0.691 # um
voxel_size_y = 0.691 # um
voxel_size_z = 2 # um

reference_size = voxel_size_x

factor_z = voxel_size_z / reference_size
factor_y = voxel_size_y / reference_size
factor_x = voxel_size_x / reference_size

viewer.layers['mask'].scale = [factor_z, factor_y, factor_x] # Z, Y, X order
viewer.dims.ndisplay = 3
#viewer.camera.center = [s//2 for s in mask.shape]
viewer.camera.zoom=5
viewer.camera.angles=(10.90517458968619, -20.777067798396835, 58.04311170773853)
viewer.camera.perspective=0.0
viewer.camera.interactive=True

# %%
viewer.camera.zoom=5
viewer.camera.angles=(-29.987043790992097, 49.57065942474976, -41.85955990611221)
viewer.camera.perspective=0.0
viewer.camera.interactive=True

# %%
from PIL import Image

viewer.camera.zoom=5
viewer.camera.angles=(-29.987043790992097, 49.57065942474976, -41.85955990611221)
viewer.camera.perspective=0.0
viewer.camera.interactive=True

for c in range(0, 5):
    print(f'processing celltype {celltype_dict[c]}')
    for n in range(0, 5):
        print(f'processing cell {n}')
        last_valid_image = None  # Store the last valid screenshot
        track_array = mask[c, n]
        if np.all(track_array == 0):
            continue
        else:
            for t in range(0, 360):
                if t == 0:
                    # Update viewer to display the current subarray
                    viewer.dims.current_step = (c, n, t, 1, 74, 74)
                    img = viewer.screenshot(size=(200, 300), scale=1, canvas_only=True, flash=False)
                    last_valid_image = (c, n, t, 1, 74, 74)
                    # Convert the NumPy array to a Pillow Image
                    image = Image.fromarray(img, mode="RGBA")

                else:
                    subarray = mask[c, n, t]  # Extract the subarray (slice for :, :, :)
                    
                    if np.all(subarray == 0):  # Check if the subarray is all zeros
                        print(f'Subarray at (c={c}, n={n}, t={t}) is all zeros, using last valid image.')
                        img = last_valid_image  # Use the last valid image
                    else:
                        # Update viewer to display the current subarray
                        viewer.dims.current_step = (c, n, t, 1, 74, 74)
                        img = viewer.screenshot(size=(200, 300), scale=1, canvas_only=True, flash=False)
                        # Convert the NumPy array to a Pillow Image
                        image = Image.fromarray(img, mode="RGBA")
                        last_valid_image = (c, n, t, 1, 74, 74)
                
                # Save the image as a PNG
                save_path = f'D:/Mari_Sixth_Dataset_Analysis/animation2/{celltype_dict[c]}/{n}_t{t}.png'
                image.save(save_path, format="PNG")
# Out:
# processing celltype basal
# processing cell 0
# Subarray at (c=0, n=0, t=71) is all zeros, using last valid image.
# Subarray at (c=0, n=0, t=72) is all zeros, using last valid image.
# Subarray at (c=0, n=0, t=155) is all zeros, using last valid image.
# Subarray at (c=0, n=0, t=263) is all zeros, using last valid image.
# Subarray at (c=0, n=0, t=288) is all zeros, using last valid image.
# Subarray at (c=0, n=0, t=340) is all zeros, using last valid image.
# processing cell 1
# Subarray at (c=0, n=1, t=166) is all zeros, using last valid image.
# Subarray at (c=0, n=1, t=192) is all zeros, using last valid image.
# Subarray at (c=0, n=1, t=193) is all zeros, using last valid image.
# Subarray at (c=0, n=1, t=195) is all zeros, using last valid image.
# Subarray at (c=0, n=1, t=197) is all zeros, using last valid image.
# Subarray at (c=0, n=1, t=198) is all zeros, using last valid image.
# Subarray at (c=0, n=1, t=344) is all zeros, using last valid image.
# processing cell 2
# Subarray at (c=0, n=2, t=62) is all zeros, using last valid image.
# Subarray at (c=0, n=2, t=158) is all zeros, using last valid image.
# Subarray at (c=0, n=2, t=159) is all zeros, using last valid image.
# Subarray at (c=0, n=2, t=167) is all zeros, using last valid image.
# Subarray at (c=0, n=2, t=168) is all zeros, using last valid image.
# Subarray at (c=0, n=2, t=176) is all zeros, using last valid image.
# Subarray at (c=0, n=2, t=203) is all zeros, using last valid image.
# Subarray at (c=0, n=2, t=241) is all zeros, using last valid image.
# Subarray at (c=0, n=2, t=244) is all zeros, using last valid image.
# Subarray at (c=0, n=2, t=261) is all zeros, using last valid image.
# processing cell 3
# Subarray at (c=0, n=3, t=1) is all zeros, using last valid image.
# Subarray at (c=0, n=3, t=2) is all zeros, using last valid image.
# Subarray at (c=0, n=3, t=3) is all zeros, using last valid image.
# Subarray at (c=0, n=3, t=4) is all zeros, using last valid image.
# Subarray at (c=0, n=3, t=5) is all zeros, using last valid image.
# Subarray at (c=0, n=3, t=6) is all zeros, using last valid image.
# Subarray at (c=0, n=3, t=7) is all zeros, using last valid image.
# Subarray at (c=0, n=3, t=8) is all zeros, using last valid image.
# Subarray at (c=0, n=3, t=9) is all zeros, using last valid image.
# Subarray at (c=0, n=3, t=139) is all zeros, using last valid image.
# Subarray at (c=0, n=3, t=204) is all zeros, using last valid image.
# Subarray at (c=0, n=3, t=222) is all zeros, using last valid image.
# Subarray at (c=0, n=3, t=316) is all zeros, using last valid image.
# Subarray at (c=0, n=3, t=358) is all zeros, using last valid image.
# processing cell 4
# Subarray at (c=0, n=4, t=19) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=20) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=39) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=40) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=41) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=71) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=75) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=77) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=81) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=100) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=132) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=141) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=158) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=167) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=190) is all zeros, using last valid image.
# Subarray at (c=0, n=4, t=217) is all zeros, using last valid image.
# processing celltype goblet
# processing cell 0
# Subarray at (c=1, n=0, t=1) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=2) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=3) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=4) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=5) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=6) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=7) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=8) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=9) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=10) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=11) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=12) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=13) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=14) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=15) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=16) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=17) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=18) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=19) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=20) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=21) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=22) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=23) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=24) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=25) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=26) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=27) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=28) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=29) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=30) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=31) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=32) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=33) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=34) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=35) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=36) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=37) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=38) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=39) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=40) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=41) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=42) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=43) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=44) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=45) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=46) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=47) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=48) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=49) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=50) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=51) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=52) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=53) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=54) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=55) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=56) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=138) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=149) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=158) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=159) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=228) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=241) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=244) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=262) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=272) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=281) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=287) is all zeros, using last valid image.
# Subarray at (c=1, n=0, t=292) is all zeros, using last valid image.
# processing cell 1
# Subarray at (c=1, n=1, t=1) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=2) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=3) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=4) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=5) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=6) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=7) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=8) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=9) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=10) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=11) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=12) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=13) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=14) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=15) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=16) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=17) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=18) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=19) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=20) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=21) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=22) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=23) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=24) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=25) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=26) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=27) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=28) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=29) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=30) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=31) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=32) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=33) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=34) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=35) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=36) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=37) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=38) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=57) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=83) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=142) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=147) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=148) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=153) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=155) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=157) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=160) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=161) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=168) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=183) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=184) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=190) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=195) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=196) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=198) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=205) is all zeros, using last valid image.
# Subarray at (c=1, n=1, t=359) is all zeros, using last valid image.
# processing cell 2
# Subarray at (c=1, n=2, t=1) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=2) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=3) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=4) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=5) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=6) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=7) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=8) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=9) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=10) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=11) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=12) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=13) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=14) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=15) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=16) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=17) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=18) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=19) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=20) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=21) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=22) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=23) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=24) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=25) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=26) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=27) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=28) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=29) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=30) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=31) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=32) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=103) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=107) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=113) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=114) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=118) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=154) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=168) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=169) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=175) is all zeros, using last valid image.
# Subarray at (c=1, n=2, t=186) is all zeros, using last valid image.
# processing cell 3
# Subarray at (c=1, n=3, t=1) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=2) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=3) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=4) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=5) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=6) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=7) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=8) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=9) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=10) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=11) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=12) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=13) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=14) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=15) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=16) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=17) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=18) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=19) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=20) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=21) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=22) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=23) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=24) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=25) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=26) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=27) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=28) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=29) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=30) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=31) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=32) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=33) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=34) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=35) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=36) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=37) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=38) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=39) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=40) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=41) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=42) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=43) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=44) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=45) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=46) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=47) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=48) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=49) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=50) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=51) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=52) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=53) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=54) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=55) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=56) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=57) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=58) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=59) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=60) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=61) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=62) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=63) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=64) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=65) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=66) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=67) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=68) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=69) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=70) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=71) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=72) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=73) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=74) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=75) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=76) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=77) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=78) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=79) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=80) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=81) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=101) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=149) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=155) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=172) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=185) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=196) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=207) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=211) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=333) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=347) is all zeros, using last valid image.
# Subarray at (c=1, n=3, t=349) is all zeros, using last valid image.
# processing cell 4
# Subarray at (c=1, n=4, t=1) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=2) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=3) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=4) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=5) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=6) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=7) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=8) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=9) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=10) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=11) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=12) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=28) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=39) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=60) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=131) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=133) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=136) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=143) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=166) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=167) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=168) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=183) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=185) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=186) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=187) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=188) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=189) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=190) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=191) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=192) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=193) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=194) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=201) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=202) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=203) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=204) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=205) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=206) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=207) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=208) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=209) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=210) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=211) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=214) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=216) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=217) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=218) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=223) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=224) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=225) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=226) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=229) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=230) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=246) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=247) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=248) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=256) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=259) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=260) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=261) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=279) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=283) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=321) is all zeros, using last valid image.
# Subarray at (c=1, n=4, t=350) is all zeros, using last valid image.
# processing celltype ic
# processing cell 0
# Subarray at (c=2, n=0, t=1) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=2) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=3) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=4) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=5) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=6) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=7) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=8) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=9) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=10) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=11) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=12) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=13) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=14) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=15) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=16) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=17) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=18) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=19) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=20) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=21) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=22) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=23) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=24) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=25) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=26) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=27) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=28) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=29) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=30) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=31) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=32) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=33) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=34) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=35) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=36) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=37) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=38) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=39) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=40) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=41) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=42) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=43) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=44) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=45) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=46) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=47) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=48) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=49) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=50) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=51) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=52) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=53) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=54) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=55) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=56) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=57) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=58) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=59) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=60) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=61) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=62) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=63) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=64) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=65) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=66) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=67) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=68) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=69) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=70) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=71) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=72) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=73) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=74) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=75) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=76) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=77) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=78) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=79) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=80) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=81) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=82) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=83) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=84) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=85) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=86) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=87) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=88) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=89) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=90) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=91) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=92) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=93) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=94) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=95) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=96) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=97) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=98) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=99) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=100) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=101) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=102) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=103) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=104) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=105) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=106) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=107) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=108) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=109) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=110) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=111) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=112) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=113) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=114) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=115) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=116) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=117) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=118) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=119) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=120) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=121) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=122) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=123) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=124) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=125) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=126) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=127) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=128) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=129) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=130) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=131) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=132) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=133) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=134) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=135) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=136) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=137) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=138) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=139) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=140) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=141) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=142) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=143) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=144) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=145) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=146) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=147) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=148) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=149) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=150) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=151) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=152) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=153) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=154) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=155) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=156) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=157) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=158) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=159) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=160) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=161) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=162) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=163) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=164) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=178) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=196) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=234) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=265) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=268) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=315) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=342) is all zeros, using last valid image.
# Subarray at (c=2, n=0, t=350) is all zeros, using last valid image.
# processing cell 1
# Subarray at (c=2, n=1, t=1) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=2) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=3) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=4) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=5) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=6) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=7) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=8) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=9) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=10) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=11) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=12) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=13) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=14) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=15) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=16) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=17) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=18) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=19) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=20) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=21) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=22) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=23) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=24) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=25) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=26) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=27) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=28) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=29) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=30) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=31) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=32) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=33) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=34) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=35) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=36) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=37) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=38) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=39) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=40) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=41) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=42) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=43) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=44) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=45) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=46) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=47) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=48) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=49) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=50) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=51) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=52) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=53) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=54) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=55) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=56) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=57) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=58) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=59) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=60) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=61) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=62) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=63) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=64) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=65) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=66) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=67) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=68) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=69) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=70) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=71) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=72) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=73) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=74) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=75) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=76) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=77) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=78) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=79) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=80) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=81) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=82) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=83) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=84) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=85) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=86) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=87) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=88) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=89) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=90) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=91) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=92) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=93) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=94) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=95) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=96) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=97) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=98) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=99) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=100) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=101) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=102) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=103) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=104) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=105) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=106) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=107) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=108) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=109) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=110) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=111) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=112) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=113) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=114) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=115) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=116) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=117) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=118) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=119) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=120) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=121) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=122) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=123) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=149) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=171) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=207) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=256) is all zeros, using last valid image.
# Subarray at (c=2, n=1, t=268) is all zeros, using last valid image.
# processing cell 2
# Subarray at (c=2, n=2, t=1) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=2) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=3) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=4) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=5) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=6) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=7) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=8) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=9) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=10) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=11) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=12) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=13) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=14) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=15) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=16) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=17) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=18) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=19) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=20) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=21) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=22) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=23) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=24) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=25) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=26) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=27) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=28) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=29) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=30) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=31) is all zeros, using last valid image.
# Subarray at (c=2, n=2, t=32) is all zeros, using last valid image.
# ...
# Subarray at (c=4, n=4, t=18) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=19) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=20) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=21) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=22) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=23) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=24) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=25) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=26) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=27) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=28) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=29) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=30) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=31) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=32) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=33) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=34) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=35) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=36) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=37) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=38) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=39) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=40) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=41) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=42) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=43) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=44) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=45) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=46) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=47) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=48) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=49) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=50) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=51) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=52) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=53) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=54) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=55) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=56) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=57) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=58) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=59) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=60) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=61) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=62) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=63) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=64) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=65) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=66) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=67) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=68) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=69) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=70) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=71) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=72) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=73) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=74) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=75) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=76) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=77) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=78) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=79) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=80) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=81) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=82) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=83) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=84) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=85) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=86) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=87) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=88) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=89) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=90) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=91) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=92) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=93) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=94) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=95) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=96) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=97) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=98) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=99) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=100) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=101) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=102) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=103) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=104) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=105) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=106) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=107) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=108) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=109) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=110) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=111) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=112) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=113) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=114) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=115) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=116) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=117) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=118) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=119) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=120) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=121) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=122) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=123) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=124) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=125) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=126) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=127) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=128) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=129) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=130) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=131) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=132) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=133) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=134) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=135) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=136) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=137) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=138) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=139) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=140) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=141) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=142) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=143) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=144) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=145) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=146) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=147) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=148) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=149) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=150) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=151) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=152) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=153) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=154) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=155) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=156) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=157) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=158) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=159) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=160) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=161) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=162) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=163) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=164) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=165) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=166) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=167) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=168) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=169) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=170) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=171) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=172) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=173) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=174) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=175) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=176) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=177) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=178) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=179) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=180) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=181) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=182) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=183) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=184) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=185) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=186) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=187) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=188) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=189) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=190) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=191) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=192) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=193) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=194) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=195) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=196) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=197) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=198) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=199) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=200) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=201) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=203) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=204) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=205) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=207) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=208) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=209) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=210) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=211) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=212) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=213) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=230) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=231) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=238) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=239) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=240) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=241) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=242) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=243) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=244) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=245) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=246) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=247) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=248) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=249) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=251) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=275) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=288) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=303) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=306) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=307) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=308) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=311) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=312) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=313) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=314) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=315) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=316) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=317) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=318) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=319) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=320) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=321) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=322) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=330) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=331) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=332) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=333) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=335) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=336) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=337) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=338) is all zeros, using last valid image.
# Subarray at (c=4, n=4, t=339) is all zeros, using last valid image.

# %%
import os

# %%
for cell_type in ['basal', 'goblet', 'ic', 'mcc', 'ssc']:#'basal', 'goblet']:#, 'ic', 'mcc', 'ssc']:
    # Define the path to the folder containing the images
    chosen_folder = f"animation2/{cell_type}"
    parent_folder = "animation2/"

    # Initialize a list to store the stacks for all `n`
    all_n_stacks = []

    # Process each `n`
    for n in range(10):
        print(f"Processing n={n}")
        # Collect all images for the current `n` in ascending `t` order
        image_files = sorted(
            [f for f in os.listdir(chosen_folder) if f.startswith(f"{n}_t") and f.endswith(".png")],
            key=lambda x: int(x.split("_t")[1].split(".")[0])  # Sort by t
        )

        if image_files:
            # Load and stack the images for this `n`
            stack = []
            for img_file in image_files:
                img_path = os.path.join(chosen_folder, img_file)
                img = np.array(Image.open(img_path))  # Load the image as a NumPy array
                stack.append(img)
            
            # Convert the stack to a NumPy array (Z-dimension stack)
            stack = np.stack(stack, axis=0)  # Shape: (360, height, width, 3)
            print(f"n={n}, stack shape: {stack.shape}")

            # Append the stack to the list of all `n` stacks
            all_n_stacks.append(stack)

    # Concatenate all `n` stacks horizontally (on the width dimension)
    final_combined_stack = np.concatenate(all_n_stacks, axis=2)  # Shape: (360, height, total_width, 3)
    print(f"Final combined stack shape: {final_combined_stack.shape}")

    # Save the final stack as a single image file
    output_path = os.path.join(parent_folder, f"{cell_type}_combined_stack.tif")

    # Convert the NumPy array back to Pillow Images for saving
    final_image = [Image.fromarray(slice_) for slice_ in final_combined_stack]
    final_image[0].save(
        output_path, 
        save_all=True, 
        append_images=final_image[1:], 
        compression="tiff_deflate"
    )

    print(f"Combined stack saved to {output_path}")
# Out:
# Processing n=0
# n=0, stack shape: (360, 200, 300, 4)
# Processing n=1
# n=1, stack shape: (360, 200, 300, 4)
# Processing n=2
# n=2, stack shape: (360, 200, 300, 4)
# Processing n=3
# n=3, stack shape: (360, 200, 300, 4)
# Processing n=4
# n=4, stack shape: (360, 200, 300, 4)
# Processing n=5
# Processing n=6
# Processing n=7
# Processing n=8
# Processing n=9
# Final combined stack shape: (360, 200, 1500, 4)
# Combined stack saved to D:/Mari_Sixth_Dataset_Analysis/animation2/basal_combined_stack.tif
# Processing n=0
# n=0, stack shape: (360, 200, 300, 4)
# Processing n=1
# n=1, stack shape: (360, 200, 300, 4)
# Processing n=2
# n=2, stack shape: (360, 200, 300, 4)
# Processing n=3
# n=3, stack shape: (360, 200, 300, 4)
# Processing n=4
# n=4, stack shape: (360, 200, 300, 4)
# Processing n=5
# Processing n=6
# Processing n=7
# Processing n=8
# Processing n=9
# Final combined stack shape: (360, 200, 1500, 4)
# Combined stack saved to D:/Mari_Sixth_Dataset_Analysis/animation2/goblet_combined_stack.tif
# Processing n=0
# n=0, stack shape: (360, 200, 300, 4)
# Processing n=1
# n=1, stack shape: (360, 200, 300, 4)
# Processing n=2
# n=2, stack shape: (360, 200, 300, 4)
# Processing n=3
# n=3, stack shape: (360, 200, 300, 4)
# Processing n=4
# n=4, stack shape: (360, 200, 300, 4)
# Processing n=5
# Processing n=6
# Processing n=7
# Processing n=8
# Processing n=9
# Final combined stack shape: (360, 200, 1500, 4)
# Combined stack saved to D:/Mari_Sixth_Dataset_Analysis/animation2/ic_combined_stack.tif
# Processing n=0
# n=0, stack shape: (360, 200, 300, 4)
# Processing n=1
# n=1, stack shape: (360, 200, 300, 4)
# Processing n=2
# n=2, stack shape: (360, 200, 300, 4)
# Processing n=3
# n=3, stack shape: (360, 200, 300, 4)
# Processing n=4
# n=4, stack shape: (360, 200, 300, 4)
# Processing n=5
# Processing n=6
# Processing n=7
# Processing n=8
# Processing n=9
# Final combined stack shape: (360, 200, 1500, 4)
# Combined stack saved to D:/Mari_Sixth_Dataset_Analysis/animation2/mcc_combined_stack.tif
# Processing n=0
# n=0, stack shape: (360, 200, 300, 4)
# Processing n=1
# n=1, stack shape: (360, 200, 300, 4)
# Processing n=2
# n=2, stack shape: (360, 200, 300, 4)
# Processing n=3
# n=3, stack shape: (360, 200, 300, 4)
# Processing n=4
# n=4, stack shape: (360, 200, 300, 4)
# Processing n=5
# Processing n=6
# Processing n=7
# Processing n=8
# Processing n=9
# Final combined stack shape: (360, 200, 1500, 4)
# Combined stack saved to D:/Mari_Sixth_Dataset_Analysis/animation2/ssc_combined_stack.tif

# %%
img.shape

# %%
viewer.dims.current_step = (0, 6, 357, 1, 74, 74)
img = viewer.screenshot(size=(200,300),scale=1,canvas_only=True,flash=False)
plt.figure(figsize=(3,3),frameon=False)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
print(viewer.camera.angles)

# %%
print(viewer.dims.current_step)

# %%
# Scale boolean values to 0-255
croppings_scaled = (croppings_array.astype(np.uint8) * 255)

# Flatten C and N into one axis
croppings_flattened = croppings_scaled.reshape(-1, *croppings_array.shape[2:])  # Shape: (C * N, T, Z, Y, X)

# %%
len(croppings_scaled[croppings_scaled != 0])

# %%
# Transpose the array to ImageJ-compatible order (T, Z, C, Y, X)
croppings_imagej_ready = np.transpose(croppings_flattened, (1, 2, 0, 3, 4))  # Shape: (T, Z, C, Y, X)

# Save with ImageJ metadata
tiff.imwrite(
    'croppings_array.tif',
    croppings_imagej_ready,
    imagej=True,
    metadata={
        'axes': 'TZCYX',  # Specify axes order for ImageJ
    }
)

# %%
# Transpose the array to ImageJ-compatible order (T, Z, C, Y, X)
croppings_napari_ready = np.transpose(croppings_flattened, (0, 1, 2, 3, 4))  # Shape: (T, Z, C, Y, X)

# Save with ImageJ metadata
tiff.imwrite('croppings_array_napari.tif', croppings_napari_ready)

# %%
croppings_napari_ready.shape

# %%
croppings_napari_ready = tiff.imread('croppings_array_napari.tif')

# %%
croppings_array = croppings_napari_ready.reshape(5, 10, 360, 10, 150, 150)
